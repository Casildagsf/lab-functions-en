# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
#your code here
    if a > b:
        return a 
    elif b > a:
        return b 
result = greater(10, 40)
print(result)
# Out:
# 40

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.032s
#
# OK

# %%
#your code here

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
#your code here

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # This will test your function
# ----> 2 test_greatest(greatest)
#
# NameError: name 'greatest' is not defined

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
#your code here
    a = 0
    for n in lst:
        a += n
    return a
lst = [1, 2, 3, 5, 6]
result = sum_all(lst)
print(result)
# Out:
# 17

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.037s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
#your code here
    a = 1
    for n in lst:
        a *= n
    return a
lst = [2, 5, 3]
result = mult_all(lst)
print(result)
# Out:
# 30

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.031s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
#your code here
    if oper == "*":
        a = 1
        for n in arr:
            a *= n
        return a
    else:
        a = 0
        for n in arr:
            a += n
        return a

result = oper_all([1, 2, 5], oper = "+")
print(result)
result = oper_all([1, 25, 2], oper = "*")
print(result)
# Out:
# 8
# 50

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.029s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
#your code here
    a = 1
    for n in range(n, 0, -1):
      a = a * n
    return a
result = factorial(5)
print(result)
# Out:
# 120

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.032s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
#your code here

    unique_list = []
    for element in lst_un:
        if element not in unique_list:
            unique_list.append(element)
        else:
            pass
    return unique_list

list = ["red", "green", "red", "blue", "red", "blue"]
print(unique(list))  # ['red', 'green', 'blue']
# Out:
# ['red', 'green', 'blue']

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
#your code here
    dictionary = {}
    for element in arr:
        if element in dictionary:
            dictionary[element] += 1
        else:
            dictionary[element] = 1
    
    mode = arr [0]
    for key in dictionary:
        if dictionary[key] > dictionary[mode]:
            mode = key
    
    return mode
list = ["red", "green", "red", "blue", "red", "blue"]
print(mode_counter(list))
# Out:
# red

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.031s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
#your code here
    n = 0
    total = 0
    for x in list_sd:
        total += x
        n += 1
    mean = total / n

    sq_diff_total = 0
    for x in list_sd:
        sq_diff_total += (x - mean) ** 2
    variance = sq_diff_total / (n - 1)

    return variance ** 0.5

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.055s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
#your code here
    return set("abcdefghijklmnopqrstuvwxyz") <= set(string.lower())

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.012s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
#your code here
    return sorted(string.split(", "))


string = "apple, banana, cherry, mango, orange"
print(sort_alpha(string))
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange']

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['vbjpb,wagn,dxof,ospj,kxsyuryp,hhseywgma[135 chars]bcg'] != 'bscjxpo,ciqlezj,dxof,gelemoewu,hhseywgma[133 chars]xgcj' : Should be bscjxpo,ciqlezj,dxof,gelemoewu,hhseywgma,hlfqqxzg,hzwepwxby,imdk,kxsyuryp,mnefgcn,ncwoyket,njmzaiytsy,njyrmn,ospj,stctn,ubbtmp,vbjpb,vugkx,wagn,wcfyhmobcg,xeqdlp,xfabbtql,zxxgcj
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['hiftqp,puryzsm,vbdyeutb,qlreat,hdhgjzag[42 chars]bni'] != 'botveknzx,ezztucsq,hdhgjzagpv,hiftqp,ijc[40 chars]bzzl' : Should be botveknzx,ezztucsq,hdhgjzagpv,hiftqp,ijcdufg,nbidbni,puryzsm,qlreat,vbdyeutb,xaqbzzl
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['ktfwuznr,ofekex,bictelw,tdxohhmsy,tvqyhulaqb,rqsodvlu'] != 'bictelw,ktfwuznr,ofekex,rqsodvlu,tdxohhmsy,tvqyhulaqb' : Should be bictelw,ktfwuznr,ofekex,rqsodvlu,tdxohhmsy,tvqyhulaqb
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['cwzsgwho,slpqsc,zwej,pcwyob,phcfhpqwpx,[77 chars]gjl'] != 'cwzsgwho,jcula,ngjl,nlsv,pcwyob,phcfhpqw[75 chars]zwej' : Should be cwzsgwho,jcula,ngjl,nlsv,pcwyob,phcfhpqwpx,qdjnciajyy,qobifne,slpqsc,uqgroyvv,vscdebg,vzfnsvdt,wqfxglso,xwgitgxbnn,zwej
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['vooah,ilqmalmxc,fqcyvksid,mbzije,ggphn,[95 chars]poo'] != 'cxkmtccjad,fqcyvksid,ggphn,gtofpoo,gxpkk[93 chars]ntpy' : Should be cxkmtccjad,fqcyvksid,ggphn,gtofpoo,gxpkkx,ilqmalmxc,imiopojoju,jbbepgaxu,lphkfsg,mbzije,nctsh,thsrxemtab,ukqetmornb,vooah,xgtomqh,znhntpy
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['myvdeuc,ihoeng,gaajcgys,uueiv,cefeo,flsvlkwcc,zjkxdadd,lagngcmbu'] != 'cefeo,flsvlkwcc,gaajcgys,ihoeng,lagngcmbu,myvdeuc,uueiv,zjkxdadd' : Should be cefeo,flsvlkwcc,gaajcgys,ihoeng,lagngcmbu,myvdeuc,uueiv,zjkxdadd
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['vijxiykja,qxmhzybha,mrpfk,fzidnzc,fhbum[106 chars]fgw'] != 'anfimn,dickoghznd,fhbumwwh,fzidnzc,ghjrv[104 chars]asyl' : Should be anfimn,dickoghznd,fhbumwwh,fzidnzc,ghjrvovmu,jwnx,mrpfk,oqvtxp,otqnsfgw,oxuohc,qxmhzybha,ryrji,sorbc,spzwqn,sweisgv,urondqvpn,vijxiykja,ydgi,zefasyl
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['hrnlgr,sgegdqqlr,vkzmjwcjm,dbaolhdo,fgg[69 chars]nik'] != 'dbaolhdo,fcywabzw,fggijto,hebbbnik,hrnlg[67 chars]gdxc' : Should be dbaolhdo,fcywabzw,fggijto,hebbbnik,hrnlgr,ilwux,khcknqqbcg,ltlypbx,ouigpcz,rysjiw,sgegdqqlr,vkzmjwcjm,xbsovgdxc
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['xkzdygdgyi,hgszzubjn,hxlukcyfli,rpth,dbvvjb,umgqs'] != 'dbvvjb,hgszzubjn,hxlukcyfli,rpth,umgqs,xkzdygdgyi' : Should be dbvvjb,hgszzubjn,hxlukcyfli,rpth,umgqs,xkzdygdgyi
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['eelpgbqz,ycxcygare,fuueke,aczxtel,faxln[147 chars]vwr'] != 'aczxtel,ajkoxpcx,alyb,bczscetomd,ctqxpqf[145 chars]qpdv' : Should be aczxtel,ajkoxpcx,alyb,bczscetomd,ctqxpqf,ecpddtpa,eelpgbqz,faxlnnjv,fuueke,liody,llufuq,lxauhhunq,msyeayvzw,pzwtmidbb,scegxmf,swinvujcsf,vfis,wsldlvwr,xyxepbmpo,ycxcygare,ynzfcqtcus,zpfqpdv
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/gsfai/Desktop/AI Engineering/Python Labs/lab-functions-en/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: ['hmzazrfytv,kvfkdr,jffsmbnju,amojz,zhygtewo,xfvvofody,teqmhejolv'] != 'amojz,hmzazrfytv,jffsmbnju,kvfkdr,teqmhejolv,xfvvofody,zhygtewo' : Should be amojz,hmzazrfytv,jffsmbnju,kvfkdr,teqmhejolv,xfvvofody,zhygtewo
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.047s
#
# FAILED (failures=100)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
#your code here
   return (len(password) >= 8 and 
           any(c in "!@#$%^&*()_+-=[]{}|;':\",./<>?" for c in password) and 
           any(c.islower() for c in password) and 
           any(c.isupper() for c in password) and 
           any(c in "1234567890" for c in password))

# %%
print("statement")
# Out:
# statement

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.054s
#
# OK
